# %% [markdown]
# <div style="text-align: center; background-color: #559cff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Lab 02 - Introduction To Data Science @ FIT-HCMUS, VNU-HCM 📌
# </div>

# %% [markdown]
# <div style="text-align: center; background-color: #b1d1ff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Stage 3.0 - Exploratory data analysis
# </div>

# %% [markdown]
# ## Import

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# YOUR CODE HERE (OPTION) 
# If you need other libraries, you can import them here
import seaborn as sns

# %% [markdown]
# ## Exploring your data

# %% [markdown]
# ### Read cleaned data from file (0.25 points)

# %% [markdown]
# We can now use the cleaned dataset for analysis. Thus, we first read the CSV files we created in the previous pre-processing task.

# %%
# YOUR CODE HERE
cleaned_df = pd.read_csv("../data/processed/21127657_europe_processed.csv")

# %%
# TEST
cleaned_df.head()
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0         2775634.0          1391086.0        1384548.0   10.813117
# 1         2811666.0          1407212.0        1404454.0   10.240000
# 2         2837849.0          1418585.0        1419264.0   10.285000
# 3         2854191.0          1425363.0        1428828.0   10.343000
# 4         2866376.0          1430495.0        1435881.0   10.517000
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0   10.096538                        9.0                  26.361868
# 1   11.325000                        9.0                  21.562780
# 2   10.785000                        9.0                  20.781540
# 3    8.480000                        9.0                  20.150670
# 4    8.308000                        9.0                  19.745660
#
#    Employment in Agriculture(%)  Female Employment in Agriculture(%)  \
# 0                      9.386339                             8.456056
# ...

# %%
# TEST
cleaned_df.shape
# Out:
# (1120, 25)

# %% [markdown]
# ### Numerical analysis using descriptive statistics (0.25 points)

# %% [markdown]
# Descriptive statistics show the characteristics of numerical features. It shows us the information such as:
# - The mean (and you can go further with advanced techiques as Arithmetic mean, Geometric mean, Harmonic mean)
# - The median
# - The mode
# - Quantiles (Quartiles, Percentiles, Deciles, Crocodiles?)
# - Range and IQR (Interquartile Range) (you might find that its relation to box plots)
# - Variance and Standard deviation (std dev)
# - Coefficient of Variation
# - Skewness
# - Kurtosis
# - Standard Error (of the sample mean)
# - Moments
# - Covariance and Correlation
#
# Due the scope of this lab, you just need to use basic function of Pandas to calculate basic descriptive statistics information and give insights from it.

# %%
df_copy = cleaned_df.drop(['Year', 'Country'], axis='columns')

# YOUR CODE HERE
df_copy.describe()
# Out:
#        Total Population  Female Population  Male Population   Birth Rate  \
# count      1.120000e+03       1.120000e+03     1.120000e+03  1120.000000
# mean       1.399210e+07       7.200463e+06     6.791642e+06    10.813117
# std        2.085705e+07       1.072965e+07     1.013146e+07     1.913733
# min        2.488600e+04       1.277900e+04     1.210700e+04     5.900000
# 25%        2.019648e+06       1.025421e+06     9.939572e+05     9.500000
# 50%        5.376422e+06       2.743866e+06     2.625598e+06    10.699000
# 75%        1.053030e+07       5.424500e+06     5.169164e+06    11.700000
# max        8.407981e+07       4.259320e+07     4.148661e+07    25.000000
#
#         Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# count  1120.000000                1120.000000                1120.000000
# mean     10.096538                  10.231975                  26.361868
# std       2.409081                   1.272694                   6.026379
# ...

# %% [markdown]
# **TODO**: Give your observation here
#
# - The above table shows the descriptive statistics of the numerical features in the dataset:
#     - The `count` is the number of non-null values in the feature. It gives us an idea of the number of missing values in the feature.
#     - The `mean` of the features is the average value of the features in the dataset. It provides an insight into the central tendency of the data.
#     - The `std` is the standard deviation of the feature. This measures the dispersion of the data around the mean in each column.
#     - The `min` and `max` are the minimum and maximum values of the feature respectively. They indicate the range of values that the data can take.
#     - The `25%`, `50%`, and `75%` are the first, second, and third quartiles respectively. They are the values that divide the data into four equal parts. The `50%` is also known as the median of the data. They provide information about the distribution's concentration.

# %% [markdown]
# ### Describe the correlation between features in the dataset (0.75 points)

# %% [markdown]
# Considering the available features within the training dataset, we want to identify and analyse the relationships between them, and then determine which features within the dataset significantly contribute to our solution goal. By using calculation and visualisation, Python allows us to create a correlation matrix, which is a table that represents the correlation coefficients between different variables.

# %% [markdown]
# Now let's make a correlation matrix, then visualize it, and describe what insights you observed?

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)

# %%
# YOUR CODE HERE
# create a copy
df_copy = cleaned_df.copy()

# Exclude the categorical features from the matrix
df_copy.drop(['Year', 'Country'], inplace=True, axis='columns')

# plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_copy.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# **Question 01**: How does the correlation between features change in the top 10 countries with the LARGEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the country population is large.

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)
def population_countries(df, is_ascending):
    # create a new dataframe
    top_10_popu_df = pd.DataFrame()
    # Find average population for each country
    top_10_popu_df["Mean population"] = df.groupby("Country")["Total Population"].mean()
    # Set the index as a column - countries
    top_10_popu_df["Country"] = top_10_popu_df.index
    # Drop the index
    top_10_popu_df.reset_index(drop=True, inplace=True)
    # Sort the rows based of Average Birth Rate
    top_10_popu_df.sort_values("Mean population", inplace=True, ascending=is_ascending)
    # Display
    return list(top_10_popu_df.head(10)['Country'])

# %%
# YOUR CODE HERE
countries = population_countries(cleaned_df, False)
print(countries)
top_population_df = cleaned_df[cleaned_df['Country'].isin(countries)]
# Exclude the categorical features from the matrix
top_population_df.drop(['Year', 'Country'], inplace=True, axis='columns')

# plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(top_population_df.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()
# Out:
# ['Germany', 'France', 'United Kingdom', 'Italy', 'Ukraine', 'Spain', 'Poland', 'Netherlands', 'Greece', 'Belgium']

# %% [markdown]
# **YOUR ANSWER**
# - Observing the `correlation matrix between features in the top 10 countries with the largest population`, we can see that the correlation between most features has significantly **increased**. If initially the features were positively correlated, now this positive correlation is **even more pronounced** (transitioning from light blue to dark blue). Similarly, if the features were initially negatively correlated, now this negative correlation has also become **more pronounced**, as evidenced by the transition from light orange to brown red. This indicates that features have a stronger correlation with each other in countries with larger populations.
# - However, there are still a **few features** that have slightly **decreased correlation**  or transitioned from positive to negative correlation, but the changes are **not significant**.

# %% [markdown]
# **Question 02**: How does the correlation between features change in the top 10 countries with the SMALLEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the conutry population is small.

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)

# %%
# YOUR CODE HERE
countries = population_countries(cleaned_df, True)
print(countries)
smallest_population_df = cleaned_df[cleaned_df['Country'].isin(countries)]
# Exclude the categorical features from the matrix
smallest_population_df.drop(['Year', 'Country'], inplace=True, axis='columns')

# plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(smallest_population_df.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()
# Out:
# ['Gibraltar', 'San Marino', 'Monaco', 'Liechtenstein', 'Faroe Islands', 'Iceland', 'Malta', 'Luxembourg', 'Estonia', 'Slovenia']

# %% [markdown]
# **YOUR ANSWER**
# - Similar to countries with the largest populations, the correlation between features in countries with the smallest populations has also significantly **increased** compared to the initial correlation. This is evident from the color transitions in the correlation matrix, with `lighter colors` shifting to `darker colors`.
# - Look more closer, the majority of feature correlations among the most population countries are significantly **higher** than those among the least populous countries (indicated by darker colors). This suggests that features in countries with the highest populations have a **higher correlation** with each other compared to countries with the lowest populations.
# - It is **possible** to drop features that have **less effect or weaker correlation** if they are not deemed significant or relevant for your analysis or modeling purposes. However, since the purpose of this analysis has not been determined yet, we will keep all the features now.

# %% [markdown]
# ## Making a question? (1.25 points)

# %% [markdown]
# After exploring the data, we have a better understanding of the data. Now let's see what questions can be answered with this data.
#
# **A possible question is:** What is the population situation of the countries on the continent today?
#
# **Answering this question will** help us to see the current population status and predictions about the future development of the labor force of the countries on the continent are under consideration.
#
# **How we answer this question**: we will consider the Average Birth Rate and Death Rate for countries across all the year.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# Step 01: construct Average Birth Rate dataframe for each country.

# %%
# Create a new dataframe
avg_birthrate_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_birthrate_df["Avg.Birth Rate"] = cleaned_df.groupby("Country")["Birth Rate"].mean()

# Set the index as a column - countries
avg_birthrate_df["Country"] = avg_birthrate_df.index

# Drop the index
avg_birthrate_df.reset_index(drop=True, inplace=True)

# Sort the rows based of Average Birth Rate
avg_birthrate_df.sort_values("Avg.Birth Rate", inplace=True, ascending=False)

# Display
avg_birthrate_df.head()
# Out:
#     Avg.Birth Rate        Country
# 18       14.346897        Ireland
# 17       13.993326        Iceland
# 0        13.738611        Albania
# 10       13.636183  Faroe Islands
# 26       13.045790        Moldova

# %%
# Plotting for top countries
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=avg_birthrate_df.head(), x="Country", y= "Avg.Birth Rate")

# %% [markdown]
# Step 02: construct Average Death Rate dataframe for each country.

# %%
# Create a new dataframe
avg_deathrate_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_deathrate_df ["Avg.Death Rate"] = cleaned_df.groupby("Country")["Death Rate"].mean()

# Set the index as a column - countries
avg_deathrate_df["Country"] = avg_deathrate_df .index

# Drop the index
avg_deathrate_df .reset_index(drop=True, inplace=True)

# Sort the rows based of Average Birth Rate
avg_deathrate_df .sort_values("Avg.Death Rate", inplace=True, ascending=False)

# Display
avg_deathrate_df .head()
# Out:
#     Avg.Death Rate   Country
# 38       15.199876   Ukraine
# 5        14.860591  Bulgaria
# 20       14.371305    Latvia
# 2        13.703341   Belarus
# 16       13.310591   Hungary

# %%
# Plotting for top countries
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=avg_deathrate_df.head(), x="Country", y= "Avg.Death Rate")

# %% [markdown]
# **TODO**: Give your obervation here
#
# - All five countries with the highest birth rates in Europe share the common characteristics of having low populations and underdeveloped economies.. However, the high birth rates serve as evidence of a youthful population, which can contribute to the economic development of the five aforementioned countries in the future.
# - `Ukraine, Bulgaria, Latvia, Belarus và Hungary` have respectively been the five countries with the highest death rates in Europe for the past 28 years. This could be due to these countries being in a stage of economic development, with a rapidly aging population leading to an increase in the death rate. Additionally, these countries also have low birth rates, resulting in a low population growth rate and contributing to the slow economic development of these countries.

# %% [markdown]
# ## Making your own question 01? (1.5 points)

# %% [markdown]
# **Question:** How does the development of a country affect life expectancy of its population??
#
# **Answering this question will** helps you understand the relationship between a country's development and the life expectancy of its people. By exploring this relationship, you can gain insights into the important factors that influence life expectancy and the changes that development can bring about.
#
# **How we answer this question**:
# - We calculate the average life expectancy of a population by taking the average of female life expectancy and male life expectancy.
# - We determine that the development of a country is reflected through features such as `National Income Capita, Employment in industry/agriculture, electric/energy consumtion`.
# - We build a correlation matrix to see how these features affect `Average life expentancy`.
# - From there, we can deduce how the development of a country affects the life expectancy of its people.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# #### Calculate the average life expectancy of a population

# %%
features_1 = ['Employment in Industry(%)','Employment in Agriculture(%)', 'National Income per Capita',
              'Electric Power Consumption(kWH per capita)','Renewable Energy Consumption (%)',
              'Fossil Fuel Consumption (%)','Male life expectancy','Female life expectancy ']
df_1 = cleaned_df[features_1]
# Combine male/female life expectancy into one column - life expectancy
df_1['Average life expectancy'] = (df_1['Female life expectancy '] + df_1['Male life expectancy'])/2
df_1.drop(['Female life expectancy ', 'Male life expectancy'], inplace=True, axis='columns')
# Move `Average life expectancy` to the first column
column = df_1.pop('Average life expectancy')
df_1.insert(0, 'Average life expectancy', column)
# display
df_1.head()
# Out:
#    Average life expectancy  Employment in Industry(%)  \
# 0                77.573006                  26.361868
# 1                76.630000                  21.562780
# 2                77.154000                  20.781540
# 3                79.417000                  20.150670
# 4                79.322500                  19.745660
#
#    Employment in Agriculture(%)  National Income per Capita  \
# 0                      9.386339                    2.465704
# 1                     34.618040                    2.465704
# 2                     35.541970                   -5.154424
# 3                     36.416850                    1.116691
# 4                     37.285730                    3.964435
#
#    Electric Power Consumption(kWH per capita)  \
# 0                                 7131.404452
# 1                                 7131.404452
# 2                                 7131.404452
# 3                                 7131.404452
# ...

# %% [markdown]
# #### Build a correlation matrix

# %%
# YOUR CODE HERE
# plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_1.corr(), annot=True, cmap='coolwarm', center=0,ax=ax)
plt.show()

# %% [markdown]
# - From the correlation matrix, we observe that:
#     - `Electric Power Consumption and Renewable Energy Consumption` have a **positive correlation** with `Average life expectancy`, indicating that they have a positive influence on the life expectancy of the population.
#     - However, other factors such as `Employment in Industry/Agriculture, National Income per Capita, and Fossil Fuel Consumption` have a **negative correlation** with `Average life expectancy`, indicating how the **adverse effects** of industrial development impact the health and life expectancy of the population.

# %% [markdown]
# ---

# %% [markdown]
# ## Making your own question 02? (1.5 points)

# %% [markdown]
# **Question:** How is the gender distribution in the most populous countries in the recent years in Europe ?
#
# **Answering this question will** helps you understand the gender balance within the population and can reveal different patterns and trends among populous countries.
#
# **How we answer this question**:
# - We calculate the male ratio in the most populous countries in Europe and then plot a bar chart to visualize the gender distribution in these countries.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# #### Calculate male ratio in the most populous countries in Europe

# %%
# create new df
df_2 = pd.DataFrame()
# Find 10 populous countries in Europe
populous_countries = population_countries(cleaned_df, False)
temp_df = cleaned_df[cleaned_df['Country'].isin(populous_countries)]
# Find average population for each country
df_2['Avg Total Population'] = temp_df.groupby("Country")["Total Population"].mean()
df_2['Avg Male Population'] = temp_df.groupby("Country")["Male Population"].mean()
# Set the index as a column - countries
df_2["Country"] = df_2.index
# Drop the index
df_2.reset_index(drop=True, inplace=True)
# Calculate sex ratio
df_2['Sex Ratio'] = df_2["Avg Male Population"]/df_2['Avg Total Population']
# display
df_2
# Out:
#    Avg Total Population  Avg Male Population         Country  Sex Ratio
# 0          1.081564e+07         5.307063e+06         Belgium   0.490684
# 1          6.411858e+07         3.105147e+07          France   0.484282
# 2          8.215120e+07         4.019720e+07         Germany   0.489307
# 3          1.085178e+07         5.364894e+06          Greece   0.494379
# 4          5.862630e+07         2.842684e+07           Italy   0.484882
# 5          1.653069e+07         8.188440e+06     Netherlands   0.495348
# 6          3.815435e+07         1.849436e+07          Poland   0.484725
# 7          4.438858e+07         2.181546e+07           Spain   0.491466
# 8          4.660210e+07         2.154788e+07         Ukraine   0.462380
# 9          6.232010e+07         3.055919e+07  United Kingdom   0.490358

# %% [markdown]
# #### Plot the bar chart

# %%
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=df_2, x="Country", y= "Sex Ratio")
# Show values on the top of each bar
for index, row in df_2.iterrows():
    value = round(row['Sex Ratio'], 3)
    ax.annotate(str(value), xy=(index, row['Sex Ratio']), ha='center', va='bottom')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
plt.show()

# %% [markdown]
# From the above bar chart, we can see that:
# - The gender ratios in 9 out of the top 10 most populous countries in Europe tend to be **balanced**. This balance is not surprising as these countries are mostly highly developed.
# - It demonstrates the effectiveness of development policies in these countries, particularly `gender-related policies`.
# - However, `Ukraine` has the most imbalanced gender ratio, with a higher proportion of females than males by around **10%**.

# %% [markdown]
# ---

# %% [markdown]
# ## Making your own question 03?

# %% [markdown]
# **Question:** Which countries have the highest average GDP per capita in recent years in Europe?
#
# **Answering this question will** allows us to observe the economic development and assess the economic well-being of countries in the region.
#
# **How we answer this question**:
# - We calculate the average GDP per capita in the last 23 years in each country. Then we plot a bar chart to visualize the average GDP per capita in the top 5 countries with the highest average GDP per capita.

# %% [markdown]
# ### Pre-processing

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# #### Calculate the average GDP per capita in the last 28 years in each country

# %%
# ceate new column
temp = cleaned_df.copy()
temp["GDP per capita"] = temp["GDP in USD"] / temp["Total Population"]
# create new df
df_3 = pd.DataFrame()
# Calculate average GDP per capita for each country in the last 28 years
df_3['Avg GDP per capita'] = temp.groupby("Country")["GDP per capita"].mean()
# Set the index as a column - countries
df_3["Country"] = df_3.index
# Drop the index
df_3.reset_index(drop=True, inplace=True)
# Sort the rows based of Average GDP per capita
df_3.sort_values("Avg GDP per capita", inplace=True, ascending=False)
# display
df_3.head()
# Out:
#     Avg GDP per capita        Country
# 14        1.372057e+07      Gibraltar
# 32        2.809146e+06     San Marino
# 10        1.323187e+06  Faroe Islands
# 27        5.487067e+05         Monaco
# 21        4.985506e+05  Liechtenstein

# %% [markdown]
# #### Plot the bar chart

# %%
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=df_3.head(), x="Country", y= "Avg GDP per capita")
plt.show()

# %% [markdown]
# Observing the bar chart above:
# - `Gibraltar` has the highest average GDP per capita in the last 28 years in Europe, followed by `San Marino, Faroe Island, Monaco and Liechtenstein`.
# - The high GDP per capita in these countries is high due to their low population rather than a high total GDP output of the entire country.

# %% [markdown]
# ---

# %% [markdown]
# ## Making your own question 04?

# %% [markdown]
# **Question:** How did the percentage of average fossil fuel consumption change in European countries from 1995 to 2022?
#
# **Answering this question will** allows us to observe the changes in the consumption of polluting and climate-changing energy sources. Based on that, we will find measures to regulate and protect the environment.
#
# **How we answer this question**:
# - Each year, we will calculate the average percentage of fossil fuel consumption for all countries in Europe.
# - Then, we will plot a line chart to illustrate the changes in the average percentage of fossil fuel consumption for European countries from 1995 to 2022.

# %% [markdown]
# ### Pre-processing

# %% [markdown]
# #### Check whether the data is reasonable

# %%
cleaned_df["Fossil Fuel Consumption (%)"].describe()
# Out:
# count    1120.000000
# mean       73.712777
# std        16.239192
# min        10.254953
# 25%        73.159773
# 50%        73.712777
# 75%        83.609269
# max       100.000000
# Name: Fossil Fuel Consumption (%), dtype: float64

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# #### Calculate the average percentage of fossil fuel consumption in Europe

# %%
# create new df
df_4 = pd.DataFrame()
df_4["Avg Fossil Fuel Consumption (%)"] = cleaned_df.groupby("Year")["Fossil Fuel Consumption (%)"].mean()
# Set the index as a column - countries
df_4["Year"] = df_4.index
# Drop the index
df_4.reset_index(drop=True, inplace=True)
# display
df_4.head()
# Out:
#    Avg Fossil Fuel Consumption (%)  Year
# 0                        75.643914  1995
# 1                        75.682465  1996
# 2                        75.671436  1997
# 3                        75.784847  1998
# 4                        75.827458  1999

# %% [markdown]
# #### Plot the line chart

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(8, 5))
sns.lineplot(x=df_4["Year"], y=df_4["Avg Fossil Fuel Consumption (%)"])
plt.xlabel("Year")
plt.ylabel("Fossil Fuels Consumption (%)")
# Display the plot
plt.show()

# %% [markdown]
# From the line chart above, we can see that:
# - The average percentage of fossil fuel consumption in European countries has **decreased** over the years. It reached its lowest point in 2015 but has since increased. However, it is still **not as high as** in the 1990s.
# - This is a **positive sign** as it indicates that European countries are gradually shifting to using more `renewable energy sources`.
# - However, the average percentage of fossil fuel consumption in European countries is still **high** (over **70%**), which is a cause for concern as it indicates that European countries are still heavily dependent on fossil fuels.

# %% [markdown]
# ---

# %% [markdown]
# ## Making your own question 05?

# %% [markdown]
# **Question:** How has the average life expectancy of male/female in European countries changed over the years?
#
# **Answering this question will** helps us better understand how the health, healthcare, and quality of life of people in Europe have improved as the economy has gradually developed.
#
# **How we answer this question**:
# - Each year, we will calculate the average life expentancy of female and male for all countries in Europe.
# - Then, we will plot two line charts to illustrate the changes in the life expentancy of male/female for European countries from 1995 to 2022.

# %% [markdown]
# ### Pre-processing

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# #### Calculate the average life expentancy of female and male in Europe from 1995 to 2022

# %%
# create new df
df_5 = pd.DataFrame()
df_5["Avg Male Life Expectancy"] = cleaned_df.groupby("Year")["Male life expectancy"].mean()
df_5["Avg Female Life Expectancy"] = cleaned_df.groupby("Year")["Female life expectancy "].mean()
# Set the index as a column - countries
df_5["Year"] = df_5.index
# Drop the index
df_5.reset_index(drop=True, inplace=True)
# display
df_5.head()
# Out:
#    Avg Male Life Expectancy  Avg Female Life Expectancy  Year
# 0                 70.827760                   78.077966  1995
# 1                 71.302885                   78.453316  1996
# 2                 71.599285                   78.687816  1997
# 3                 71.854435                   78.862416  1998
# 4                 72.143685                   79.051391  1999

# %% [markdown]
# #### Plot the line charts to demonstray how life expectancy of people in Europe has changed

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(8, 5))
sns.lineplot(y=df_5["Avg Female Life Expectancy"], x=df_5["Year"], label="Female")
sns.lineplot(y=df_5["Avg Male Life Expectancy"], x=df_5["Year"], label="Male")
plt.xlabel("Year")
plt.ylabel("Averrage Life Expectancy")
# Display the plot
plt.legend()
plt.show()

# %% [markdown]
# From the line chart above, we can observe that:
# - The average life expectancy of European citizens has significantly **increased** (although it has decreased in recent years, it is still higher than in the 1990s).
# - The average life expectancy of women in Europe is noticeably **higher** than that of men (evidenced by the fact that the `blue line` is always above the `orange line`, even the `lowest point of the blue line` is higher than the `highest point of the orange line`). This can be explained by the fact that women are less exposed to physically demanding and hazardous work compared to men.
# - Overall, thanks to `economic` and `scientific advancements`, the overall well-being and mental health of European citizens have significantly improved, leading to an extended life expectancy.

# %% [markdown]
# ---

# %% [markdown]
# ## Making your own question 06?

# %% [markdown]
# **Question:** What is the situation of unemployment in Europe in the recent years?
#
# **Answering this question will** helps us to understand the employment situation and the economy of countries in the region. It also provides an overview of the level of job availability and allows for comparisons between countries.
# **How we answer this question**:
# - We will consider the Average Unemployment ratio for top 5 `populous countries` and top 5 `unpopulated countries` across all the year.

# %% [markdown]
# ### Pre-processing

# %% [markdown]
# #### Check whether the data is reasonable

# %%
cleaned_df["Unemployment(%)"].describe()
# Out:
# count    1120.000000
# mean        9.451621
# std         5.900909
# min         1.810000
# 25%         5.617500
# 50%         8.385500
# 75%        10.657500
# max        38.800000
# Name: Unemployment(%), dtype: float64

# %% [markdown]
# - The range of all the values in the `Unemployment` column must be from `0` to `100`. As we see, there are not any value that are outside that range, so we don't need to be worry.

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# #### Calculate the average unemployment ratio for top 5 populous countries across all the year

# %%
# Get top 5 populous countries and their data
populous_countries1 = population_countries(cleaned_df, False)[:5]
temp_df = cleaned_df[cleaned_df['Country'].isin(populous_countries1)]
# create new df
df_6a = pd.DataFrame()
df_6a["Avg Unemployment(%)"] = temp_df.groupby("Country")["Unemployment(%)"].mean()
# Set the index as a column - countries
df_6a["Country"] = df_6a.index
# Drop the index
df_6a.reset_index(drop=True, inplace=True)
# display
df_6a
# Out:
#    Avg Unemployment(%)         Country
# 0             9.421964          France
# 1             6.903893         Germany
# 2             9.823357           Italy
# 3             8.755058         Ukraine
# 4             5.778536  United Kingdom

# %% [markdown]
# #### Calculate the average unemployment ratio for top 5 unpopulated countries across all the year

# %%
# Get top 5 unpopulated countries and their data
unpopulated_countries = population_countries(cleaned_df, True)[:5]
temp_df = cleaned_df[cleaned_df['Country'].isin(unpopulated_countries)]
# create new df
df_6b = pd.DataFrame()
df_6b["Avg Unemployment(%)"] = temp_df.groupby("Country")["Unemployment(%)"].mean()
# Set the index as a column - countries
df_6b["Country"] = df_6b.index
# Drop the index
df_6b.reset_index(drop=True, inplace=True)
# display
df_6b
# Out:
#    Avg Unemployment(%)        Country
# 0             9.451621  Faroe Islands
# 1             9.451621      Gibraltar
# 2             9.451621  Liechtenstein
# 3             9.451621         Monaco
# 4             9.451621     San Marino

# %% [markdown]
# #### Visualizing

# %%
sns.set(style="whitegrid")
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
# Plot for top 5 populous countries
sns.barplot(x=df_6a["Country"], y=df_6a["Avg Unemployment(%)"], ax=ax1)
ax1.set_title("Average Unemployment in Top 5 Populous Contries in Europe")
ax1.set_ylabel("Average Unemployment (%)")
ax1.set_xlabel("Country")
# Plot for top 5 unpopulated countries
sns.barplot(x=df_6b["Country"], y=df_6b["Avg Unemployment(%)"], ax=ax2)
ax2.set_xlabel("Country")
ax2.set_ylabel("Average Unemployment (%)")
# Display
plt.tight_layout()
plt.show()

# %% [markdown]
# From 2 bar charts above:
# - The unemployment rates in the five most populous countries in Europe are **low**. The lowest is in the `United Kingdom`, and the highest is in `Italy`. However, these rates are still **lower** than the unemployment rates in the least populous countries in Europe.
# - This indicates that in populated countries, there are significantly better `job opportunities` and `working conditions` compared to less populated countries. It also reflects the `economic superiority` of densely populated countries in Europe compared to the rest.

# %% [markdown]
# ---

# %% [markdown]
# ## Making your own question 07?

# %% [markdown]
# **Question:** How does the Europe's employment changed from 1995 to 2022?
#
# **Answering this question**: will help us know how the employment in Europe from the past until now. And how labors distribute in specific fields(Agriculture, Industry, others). As a result, we can predict the trend of employment in the future.
#
# **How we answer this question**:
# - we will consider `Employment in Agriculture(%)`, `Employment in Industry(%)` and `Employment in others (%)` of all countries in Europe each year.

# %% [markdown]
# ### Pre-processing

# %% [markdown]
# #### Check whether the values in the `Employment in Agriculture(%)` and `Employment in Industry(%)` columns are reasonable

# %%
cleaned_df["Employment in Industry(%)"].describe()
# Out:
# count    1120.000000
# mean       26.361868
# std         6.026379
# min         9.394252
# 25%        22.301050
# 50%        26.361868
# 75%        30.384885
# max        43.132850
# Name: Employment in Industry(%), dtype: float64

# %%
cleaned_df["Employment in Agriculture(%)"].describe()
# Out:
# count    1120.000000
# mean        9.386339
# std         9.186978
# min         0.681637
# 25%         3.570461
# 50%         7.010980
# 75%        10.308420
# max        53.234490
# Name: Employment in Agriculture(%), dtype: float64

# %% [markdown]
# - All the values are in the range from `0` to `100`, so we don't need to be worry.

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# #### Calculate the average employment in Agriculture, Industry and others of all countries in Europe each year

# %%
# create new df
df_7 = pd.DataFrame()
# Find average for each country
df_7["Avg Employment in Industry(%)"] = cleaned_df.groupby("Year")["Employment in Industry(%)"].mean()
df_7["Avg Employment in Agriculture(%)"] = cleaned_df.groupby("Year")["Employment in Agriculture(%)"].mean()
df_7["Avg Employment in others(%)"] = 100 - df_7["Avg Employment in Industry(%)"] - df_7["Avg Employment in Agriculture(%)"]
# Set the index as a column - countries
df_7["Year"] = df_7.index
# Drop the index
df_7.reset_index(drop=True, inplace=True)
# display
df_7.head()
# Out:
#    Avg Employment in Industry(%)  Avg Employment in Agriculture(%)  \
# 0                      29.410572                         12.744480
# 1                      28.945545                         12.495269
# 2                      28.790306                         12.226384
# 3                      28.883434                         11.988248
# 4                      28.308226                         11.732194
#
#    Avg Employment in others(%)  Year
# 0                    57.844948  1995
# 1                    58.559186  1996
# 2                    58.983310  1997
# 3                    59.128318  1998
# 4                    59.959580  1999

# %% [markdown]
# #### Visualizing

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(8, 5))
sns.lineplot(y=df_7["Avg Employment in Agriculture(%)"], x=df_7["Year"], label="Agriculture")
sns.lineplot(y=df_7["Avg Employment in Industry(%)"], x=df_7["Year"], label="Industry")
sns.lineplot(y=df_7["Avg Employment in others(%)"], x=df_7["Year"], label="Others")
plt.xlabel("Year")
plt.ylabel("Employment (%)")
# Display the plot
plt.legend()
plt.show()

# %% [markdown]
# From the line chart above:
# - We have observed that the employment in both `agriculture and industry` has **decreased** in the recent years, although there has been a slight increase in the last 2 years, it is still not comparable to the past.
# - This can be explained by the development of other sectors such as `tourism, healthcare, information technology`, etc. The advancement of these sectors has caused traditional industries like agriculture and industry to become **less developed**.

# %% [markdown]
# ---

# %% [markdown]
# ## Making your own question 08?

# %% [markdown]
# **A question is:** How has the school enrollment (tertiary) in Germany changed over time?
#
# **Answering this question will** helps us to understand the trends and changes in enrollment in higher education in `Germany`. This can provide an overview of the development and progress of the education system in the `Germany`.
#
# **How we answer this question**:
# - We will determine the changes in the school enrollment (tertiary) (%) in Germany from 1995 to 2022.

# %% [markdown]
# ### Pre-processing

# %% [markdown]
# #### Check whether the data is reasonable

# %%
cleaned_df["School enrollment, tertiary"][cleaned_df["Country"] == "Germany"].describe()
# Out:
# count    28.000000
# mean     60.957390
# std       6.969289
# min      46.435570
# 25%      58.904857
# 50%      58.904857
# 75%      65.874962
# max      75.665543
# Name: School enrollment, tertiary, dtype: float64

# %% [markdown]
# - All the values are in the range from `0` to `100`, so we don't need to handle errors.

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# #### Determine school enrollment (tertiary) in Germany from 1995 to 2022

# %%
# create new df
df_8 = cleaned_df[["School enrollment, tertiary", "Year"]][cleaned_df["Country"] == "Germany"]
# display
df_8.head()
# Out:
#      School enrollment, tertiary  Year
# 364                    58.904857  2022
# 365                    75.665543  2021
# 366                    72.389420  2020
# 367                    72.705078  2019
# 368                    69.163429  2018

# %% [markdown]
# #### Plot a line chart to visualize the changes

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(8, 5))
sns.lineplot(y=df_8["School enrollment, tertiary"], x=df_8["Year"])
# customize settings
plt.xlabel("Year")
plt.ylabel("School Enrollment, Tertiary (%)")
# Display the plot
plt.show()

# %% [markdown]
# From the line chart above:
# - The university enrollment rate in `Germany` has significantly **increased** over time. This is evidence of the development of the education system in `Germany`.
# - Surprisingly, this rate **decreased** significantly last year. This can be explained by the impact of the     `Covid-19` pandemic.
# - However, the university enrollment rate in Germany is still high compared to other countries. It is predicted that in the future, the workforce in Germany will be better trained.

# %% [markdown]
# ---
